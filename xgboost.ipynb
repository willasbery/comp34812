# %%
import logging
import pandas as pd
from pathlib import Path
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, matthews_corrcoef
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
import os
import torch

# Set up logging
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO)

# %%
# Path configuration
DATA_DIR = Path('./data')
TRAIN_PATH = DATA_DIR / 'train.csv'
DEV_PATH = DATA_DIR / 'dev.csv'
MODEL_SAVE_PATH = Path('./models')
MODEL_SAVE_PATH.mkdir(parents=True, exist_ok=True)

# Optuna config
N_TRIALS = 100  # Number of Optuna trials

# %%
def get_device() -> torch.device:
    """Determine the device to use for computations."""
    if torch.cuda.is_available():
        return torch.device('cuda')
    elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        return torch.device('mps')
    else:
        return torch.device('cpu')

# %%
def prepare_data(train_df, dev_df):
    """Prepare data for XGBoost training."""
    # Combine claim and evidence into a single text feature for TF-IDF
    train_df['text'] = train_df['Claim'] + " [SEP] " + train_df['Evidence']
    dev_df['text'] = dev_df['Claim'] + " [SEP] " + dev_df['Evidence']
    
    # Extract labels
    train_labels = train_df['label'].values
    dev_labels = dev_df['label'].values
    
    return train_df, dev_df, train_labels, dev_labels

# %%
def calculate_all_metrics(y_true, y_pred):
    """
    Calculate comprehensive evaluation metrics.
    
    Returns:
        dict: Dictionary containing all metrics
    """
    # Basic accuracy
    accuracy = accuracy_score(y_true, y_pred)
    
    # Calculate precision, recall, f1 (macro)
    macro_precision, macro_recall, macro_f1, _ = precision_recall_fscore_support(
        y_true, y_pred, average='macro'
    )
    
    # Calculate precision, recall, f1 (weighted)
    weighted_precision, weighted_recall, weighted_f1, _ = precision_recall_fscore_support(
        y_true, y_pred, average='weighted'
    )
    
    # Matthews Correlation Coefficient
    mcc = matthews_corrcoef(y_true, y_pred)
    
    metrics = {
        'Accuracy': accuracy,
        'Macro-P': macro_precision,
        'Macro-R': macro_recall,
        'Macro-F1': macro_f1,
        'W Macro-P': weighted_precision,
        'W Macro-R': weighted_recall,
        'W Macro-F1': weighted_f1,
        'MCC': mcc
    }
    
    return metrics

# %%
def objective(trial):
    """Optuna objective function for hyperparameter optimization."""
    # Load data
    logging.info("Loading datasets...")
    train_df = pd.read_csv(TRAIN_PATH)
    dev_df = pd.read_csv(DEV_PATH)
    
    logging.info(f"Training data shape: {train_df.shape}")
    logging.info(f"Development data shape: {dev_df.shape}")
    
    # Prepare data
    train_df, dev_df, train_labels, dev_labels = prepare_data(train_df, dev_df)
    
    # TF-IDF vectorizer parameters
    max_features = trial.suggest_categorical("max_features", [5000, 10000, 15000, 20000])
    min_df = trial.suggest_categorical("min_df", [1, 2, 3])
    ngram_range = trial.suggest_categorical("ngram_range", [(1, 1), (1, 2), (1, 3)])
    
    # XGBoost hyperparameters
    xgb_params = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 7),
        'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'use_label_encoder': False,
        'tree_method': 'hist',
        'random_state': 42
    }
    
    # Create pipeline
    pipeline = Pipeline([
        ('tfidf', TfidfVectorizer(
            max_features=max_features,
            min_df=min_df,
            ngram_range=ngram_range,
            stop_words='english'
        )),
        ('scaler', StandardScaler(with_mean=False)),  # TF-IDF matrices are sparse
        ('xgb', xgb.XGBClassifier(
            **xgb_params,
            enable_categorical=True  # Enable categorical feature support
        ))
    ])
    
    # Train model
    logging.info(f"Training XGBoost with hyperparameters: {xgb_params}")
    
    X_train = pipeline.named_steps['tfidf'].fit_transform(train_df['text'])
    X_train = pipeline.named_steps['scaler'].fit_transform(X_train)
    
    X_dev = pipeline.named_steps['tfidf'].transform(dev_df['text'])
    X_dev = pipeline.named_steps['scaler'].transform(X_dev)
    
    # Create DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=train_labels)
    ddev = xgb.DMatrix(X_dev, label=dev_labels)
    
    # Train model
    model = xgb.train(
        xgb_params,
        dtrain,
        num_boost_round=xgb_params['n_estimators'],
        evals=[(ddev, 'eval')],
        early_stopping_rounds=50,
        verbose_eval=False
    )
    
    # Make predictions
    dev_preds = (model.predict(ddev) >= 0.5).astype(int)    
    metrics = calculate_all_metrics(dev_labels, dev_preds)
    
    # Report intermediate values for pruning
    trial.report(metrics['W Macro-F1'], step=model.best_iteration)
    if trial.should_prune():
        raise optuna.exceptions.TrialPruned()
    
    return metrics['W Macro-F1']

# %%
if __name__ == "__main__":
    print("\nHYPERPARAMETER TUNING")
    print("=====================")
    print(f"Running {N_TRIALS} trials...")
    
    # Check if GPU is available
    device = get_device()
    if torch.cuda.is_available():
        # Enable GPU acceleration for XGBoost
        os.environ['CUDA_VISIBLE_DEVICES'] = '0'
    logging.info(f"Using device: {device}")
    
    # Create a study with TPE sampler and MedianPruner
    sampler = TPESampler(seed=42)
    pruner = MedianPruner(n_startup_trials=5, n_warmup_steps=5, interval_steps=2)
    
    study = optuna.create_study(
        direction='maximize',
        sampler=sampler,
        pruner=pruner,
        study_name='xgboost_evidence_detection'
    )
    
    try:
        study.optimize(objective, n_trials=N_TRIALS, n_jobs=-1)
    except KeyboardInterrupt:
        print("Hyperparameter tuning interrupted.")
    
    print("\nBest trial:")
    trial = study.best_trial
    print(f"  Value (Accuracy): {trial.value}")
    print("  Params:")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")
# Out:
# 2025-03-26 19:00:23 - Using device: cpu
# [I 2025-03-26 19:00:23,209] A new study created in memory with name: xgboost_evidence_detection
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# HYPERPARAMETER TUNING
# =====================
# Running 100 trials...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Loading datasets...
# 2025-03-26 19:00:23 - Training data shape: (21508, 3)
# 2025-03-26 19:00:23 - Training data shape: (21508, 3)
# 2025-03-26 19:00:23 - Training data shape: (21508, 3)
# 2025-03-26 19:00:23 - Development data shape: (5926, 3)
# 2025-03-26 19:00:23 - Training data shape: (21508, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:23 - Training data shape: (21508, 3)
# 2025-03-26 19:00:23 - Training data shape: (21508, 3)
# 2025-03-26 19:00:23 - Training data shape: (21508, 3)
# 2025-03-26 19:00:23 - Development data shape: (5926, 3)
# 2025-03-26 19:00:23 - Training data shape: (21508, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# 2025-03-26 19:00:24 - Training data shape: (21508, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Training data shape: (21508, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Training XGBoost with hyperparameters: {'max_depth': 4, 'learning_rate': 0.158925074108929, 'n_estimators': 864, 'min_child_weight': 6, 'gamma': 0.013937552566816211, 'subsample': 0.9950336178324377, 'colsample_bytree': 0.5732174199977808, 'reg_alpha': 1.4795894642524775e-07, 'reg_lambda': 2.321952753677158e-07, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# 2025-03-26 19:00:24 - Training data shape: (21508, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Training data shape: (21508, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# 2025-03-26 19:00:24 - Training data shape: (21508, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Training data shape: (21508, 3)
# 2025-03-26 19:00:24 - Training XGBoost with hyperparameters: {'max_depth': 4, 'learning_rate': 0.0005049939515179142, 'n_estimators': 344, 'min_child_weight': 3, 'gamma': 0.015788326874461748, 'subsample': 0.7264047896102254, 'colsample_bytree': 0.5732944646129288, 'reg_alpha': 0.0011362560521137254, 'reg_lambda': 0.37688143768151455, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Training XGBoost with hyperparameters: {'max_depth': 4, 'learning_rate': 0.00011376986738937159, 'n_estimators': 714, 'min_child_weight': 2, 'gamma': 0.000904983303502658, 'subsample': 0.779524762824769, 'colsample_bytree': 0.6652001476102487, 'reg_alpha': 0.006474622747694848, 'reg_lambda': 2.0194515748007183e-08, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# 2025-03-26 19:00:24 - Training data shape: (21508, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Training XGBoost with hyperparameters: {'max_depth': 5, 'learning_rate': 0.0034842774613547487, 'n_estimators': 515, 'min_child_weight': 1, 'gamma': 6.319905019320346e-07, 'subsample': 0.9361532363666731, 'colsample_bytree': 0.9102143521687318, 'reg_alpha': 1.010164612380545e-05, 'reg_lambda': 9.987364951376714e-06, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:24 - Training data shape: (21508, 3)
# 2025-03-26 19:00:24 - Development data shape: (5926, 3)
# 2025-03-26 19:00:24 - Training XGBoost with hyperparameters: {'max_depth': 5, 'learning_rate': 0.09030298283573727, 'n_estimators': 722, 'min_child_weight': 3, 'gamma': 1.4103842716616918e-08, 'subsample': 0.573879628005673, 'colsample_bytree': 0.8756673879123242, 'reg_alpha': 7.782488780213041e-05, 'reg_lambda': 0.008133462167472814, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:24 - Training XGBoost with hyperparameters: {'max_depth': 5, 'learning_rate': 0.025372133505426962, 'n_estimators': 673, 'min_child_weight': 6, 'gamma': 8.189807901972068e-07, 'subsample': 0.5670373460650038, 'colsample_bytree': 0.75935648919503, 'reg_alpha': 5.775672321724279e-08, 'reg_lambda': 0.012315912604308294, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:25 - Development data shape: (5926, 3)
# 2025-03-26 19:00:25 - Training XGBoost with hyperparameters: {'max_depth': 9, 'learning_rate': 0.0003569661442289559, 'n_estimators': 623, 'min_child_weight': 7, 'gamma': 1.1408176398353025e-06, 'subsample': 0.8573583169245326, 'colsample_bytree': 0.6029586570681305, 'reg_alpha': 1.7377274463230738e-05, 'reg_lambda': 0.09490249391605789, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:25 - Development data shape: (5926, 3)
# 2025-03-26 19:00:25 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:27 - Training XGBoost with hyperparameters: {'max_depth': 7, 'learning_rate': 0.015057625567984035, 'n_estimators': 200, 'min_child_weight': 5, 'gamma': 1.5592305894355847e-08, 'subsample': 0.8801520950864359, 'colsample_bytree': 0.9237276316911296, 'reg_alpha': 1.1812979679241904e-06, 'reg_lambda': 5.287312623955868e-05, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:28 - Training XGBoost with hyperparameters: {'max_depth': 9, 'learning_rate': 0.06822777027883305, 'n_estimators': 191, 'min_child_weight': 3, 'gamma': 0.000727638169826683, 'subsample': 0.875325084570756, 'colsample_bytree': 0.5916139462043802, 'reg_alpha': 3.366194245735797e-08, 'reg_lambda': 1.8217008213714428e-06, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:28 - Training XGBoost with hyperparameters: {'max_depth': 4, 'learning_rate': 0.13516250169207422, 'n_estimators': 312, 'min_child_weight': 6, 'gamma': 9.404557459186165e-05, 'subsample': 0.843822334757016, 'colsample_bytree': 0.5124152162271078, 'reg_alpha': 2.689224210574207e-08, 'reg_lambda': 9.725911628904886e-05, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:29 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:29 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:29 - Training XGBoost with hyperparameters: {'max_depth': 9, 'learning_rate': 0.07435725577205494, 'n_estimators': 893, 'min_child_weight': 2, 'gamma': 1.8027333838201567e-07, 'subsample': 0.9839901666366928, 'colsample_bytree': 0.5949355555312226, 'reg_alpha': 0.0009362817182242818, 'reg_lambda': 5.702698096017085e-08, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:30 - Training XGBoost with hyperparameters: {'max_depth': 5, 'learning_rate': 0.004361834100919547, 'n_estimators': 411, 'min_child_weight': 1, 'gamma': 1.901618567962155e-08, 'subsample': 0.9881735226237138, 'colsample_bytree': 0.9448912021219733, 'reg_alpha': 9.605102561377187e-06, 'reg_lambda': 0.20912152216971558, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:00:31 - Training XGBoost with hyperparameters: {'max_depth': 5, 'learning_rate': 0.00018837477693353988, 'n_estimators': 865, 'min_child_weight': 4, 'gamma': 5.101221077335369e-05, 'subsample': 0.7950619290291803, 'colsample_bytree': 0.8772167583193249, 'reg_alpha': 5.665426118291153e-07, 'reg_lambda': 1.8102938578345275e-06, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:32 - Training XGBoost with hyperparameters: {'max_depth': 8, 'learning_rate': 0.05772259553862128, 'n_estimators': 182, 'min_child_weight': 6, 'gamma': 0.011892037528384665, 'subsample': 0.5381251040268005, 'colsample_bytree': 0.8495486169913646, 'reg_alpha': 1.8254444607838518e-08, 'reg_lambda': 0.0019334852036183923, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:34 - Training XGBoost with hyperparameters: {'max_depth': 4, 'learning_rate': 0.016183730871947327, 'n_estimators': 383, 'min_child_weight': 5, 'gamma': 0.009121538762017612, 'subsample': 0.5250498868787961, 'colsample_bytree': 0.8648443725871197, 'reg_alpha': 0.09345378842995437, 'reg_lambda': 3.285976658535036e-07, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:00:36 - Training XGBoost with hyperparameters: {'max_depth': 5, 'learning_rate': 0.0005571780909567404, 'n_estimators': 181, 'min_child_weight': 1, 'gamma': 3.293044599039116e-08, 'subsample': 0.9363186373991895, 'colsample_bytree': 0.7002842768067179, 'reg_alpha': 0.00784067325669551, 'reg_lambda': 0.007522433726969778, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [I 2025-03-26 19:02:56,442] Trial 15 finished with value: 0.607102296650199 and parameters: {'max_features': 10000, 'min_df': 3, 'ngram_range': (1, 2), 'max_depth': 5, 'learning_rate': 0.0005571780909567404, 'n_estimators': 181, 'min_child_weight': 1, 'gamma': 3.293044599039116e-08, 'subsample': 0.9363186373991895, 'colsample_bytree': 0.7002842768067179, 'reg_alpha': 0.00784067325669551, 'reg_lambda': 0.007522433726969778}. Best is trial 15 with value: 0.607102296650199.
# 2025-03-26 19:02:56 - Loading datasets...
# 2025-03-26 19:02:57 - Training data shape: (21508, 3)
# 2025-03-26 19:02:57 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:02:57 - Training XGBoost with hyperparameters: {'max_depth': 6, 'learning_rate': 0.00032509155710081324, 'n_estimators': 410, 'min_child_weight': 6, 'gamma': 1.1156779876467586e-06, 'subsample': 0.5273193945679318, 'colsample_bytree': 0.5360171868425565, 'reg_alpha': 0.05391508492657412, 'reg_lambda': 4.1670574502860933e-07, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [I 2025-03-26 19:03:12,922] Trial 2 finished with value: 0.607102296650199 and parameters: {'max_features': 5000, 'min_df': 3, 'ngram_range': (1, 1), 'max_depth': 4, 'learning_rate': 0.0005049939515179142, 'n_estimators': 344, 'min_child_weight': 3, 'gamma': 0.015788326874461748, 'subsample': 0.7264047896102254, 'colsample_bytree': 0.5732944646129288, 'reg_alpha': 0.0011362560521137254, 'reg_lambda': 0.37688143768151455}. Best is trial 15 with value: 0.607102296650199.
# 2025-03-26 19:03:12 - Loading datasets...
# 2025-03-26 19:03:13 - Training data shape: (21508, 3)
# 2025-03-26 19:03:13 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:03:14 - Training XGBoost with hyperparameters: {'max_depth': 3, 'learning_rate': 0.04820281199820781, 'n_estimators': 459, 'min_child_weight': 5, 'gamma': 3.424811507676058e-08, 'subsample': 0.9471097545889284, 'colsample_bytree': 0.61895507092662, 'reg_alpha': 3.586829114599832e-07, 'reg_lambda': 0.07877026822246484, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:03:21,624] Trial 8 finished with value: 0.7644367599604345 and parameters: {'max_features': 20000, 'min_df': 2, 'ngram_range': (1, 2), 'max_depth': 4, 'learning_rate': 0.13516250169207422, 'n_estimators': 312, 'min_child_weight': 6, 'gamma': 9.404557459186165e-05, 'subsample': 0.843822334757016, 'colsample_bytree': 0.5124152162271078, 'reg_alpha': 2.689224210574207e-08, 'reg_lambda': 9.725911628904886e-05}. Best is trial 8 with value: 0.7644367599604345.
# 2025-03-26 19:03:21 - Loading datasets...
# 2025-03-26 19:03:22 - Training data shape: (21508, 3)
# 2025-03-26 19:03:22 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:03:22 - Training XGBoost with hyperparameters: {'max_depth': 6, 'learning_rate': 0.0003534438009123692, 'n_estimators': 457, 'min_child_weight': 4, 'gamma': 1.0543369188670383e-08, 'subsample': 0.8231571221086877, 'colsample_bytree': 0.9018226353326928, 'reg_alpha': 2.1719632430553386e-07, 'reg_lambda': 0.011380195882582374, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:03:37,404] Trial 13 finished with value: 0.7471391189429334 and parameters: {'max_features': 20000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 8, 'learning_rate': 0.05772259553862128, 'n_estimators': 182, 'min_child_weight': 6, 'gamma': 0.011892037528384665, 'subsample': 0.5381251040268005, 'colsample_bytree': 0.8495486169913646, 'reg_alpha': 1.8254444607838518e-08, 'reg_lambda': 0.0019334852036183923}. Best is trial 8 with value: 0.7644367599604345.
# 2025-03-26 19:03:37 - Loading datasets...
# 2025-03-26 19:03:39 - Training data shape: (21508, 3)
# 2025-03-26 19:03:39 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:03:39 - Training XGBoost with hyperparameters: {'max_depth': 8, 'learning_rate': 0.00013815109506656203, 'n_estimators': 630, 'min_child_weight': 4, 'gamma': 0.0008037104443200674, 'subsample': 0.7811247916308385, 'colsample_bytree': 0.5772566349422565, 'reg_alpha': 0.00046128452910092747, 'reg_lambda': 0.003655211933933186, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:03:41,337] Trial 9 finished with value: 0.7562343751410949 and parameters: {'max_features': 5000, 'min_df': 3, 'ngram_range': (1, 2), 'max_depth': 9, 'learning_rate': 0.06822777027883305, 'n_estimators': 191, 'min_child_weight': 3, 'gamma': 0.000727638169826683, 'subsample': 0.875325084570756, 'colsample_bytree': 0.5916139462043802, 'reg_alpha': 3.366194245735797e-08, 'reg_lambda': 1.8217008213714428e-06}. Best is trial 8 with value: 0.7644367599604345.
# 2025-03-26 19:03:41 - Loading datasets...
# 2025-03-26 19:03:44 - Training data shape: (21508, 3)
# 2025-03-26 19:03:44 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:03:45 - Training XGBoost with hyperparameters: {'max_depth': 8, 'learning_rate': 0.00010587690784716988, 'n_estimators': 202, 'min_child_weight': 5, 'gamma': 2.320719748736625e-06, 'subsample': 0.9481381977456464, 'colsample_bytree': 0.5930483552723809, 'reg_alpha': 1.014432879985698e-05, 'reg_lambda': 5.989298856340018e-08, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:03:59,153] Trial 14 finished with value: 0.6996873122285864 and parameters: {'max_features': 15000, 'min_df': 2, 'ngram_range': (1, 1), 'max_depth': 4, 'learning_rate': 0.016183730871947327, 'n_estimators': 383, 'min_child_weight': 5, 'gamma': 0.009121538762017612, 'subsample': 0.5250498868787961, 'colsample_bytree': 0.8648443725871197, 'reg_alpha': 0.09345378842995437, 'reg_lambda': 3.285976658535036e-07}. Best is trial 8 with value: 0.7644367599604345.
# 2025-03-26 19:03:59 - Loading datasets...
# 2025-03-26 19:03:59 - Training data shape: (21508, 3)
# 2025-03-26 19:03:59 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:03:59 - Training XGBoost with hyperparameters: {'max_depth': 3, 'learning_rate': 0.09848799712772183, 'n_estimators': 791, 'min_child_weight': 4, 'gamma': 5.741020917644476e-05, 'subsample': 0.93205122690866, 'colsample_bytree': 0.6040987621943334, 'reg_alpha': 3.213432491916558e-06, 'reg_lambda': 0.006934809920254957, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:04:06,838] Trial 4 finished with value: 0.7008736677156385 and parameters: {'max_features': 20000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 7, 'learning_rate': 0.015057625567984035, 'n_estimators': 200, 'min_child_weight': 5, 'gamma': 1.5592305894355847e-08, 'subsample': 0.8801520950864359, 'colsample_bytree': 0.9237276316911296, 'reg_alpha': 1.1812979679241904e-06, 'reg_lambda': 5.287312623955868e-05}. Best is trial 8 with value: 0.7644367599604345.
# 2025-03-26 19:04:07 - Loading datasets...
# 2025-03-26 19:04:11 - Training data shape: (21508, 3)
# 2025-03-26 19:04:11 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:04:11 - Training XGBoost with hyperparameters: {'max_depth': 6, 'learning_rate': 0.08504830666172643, 'n_estimators': 518, 'min_child_weight': 6, 'gamma': 0.001322734035745494, 'subsample': 0.8944743276906826, 'colsample_bytree': 0.9925977103214219, 'reg_alpha': 0.0001390013750248879, 'reg_lambda': 0.003060334489319371, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:05:48,014] Trial 11 finished with value: 0.6617706171063052 and parameters: {'max_features': 10000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 5, 'learning_rate': 0.004361834100919547, 'n_estimators': 411, 'min_child_weight': 1, 'gamma': 1.901618567962155e-08, 'subsample': 0.9881735226237138, 'colsample_bytree': 0.9448912021219733, 'reg_alpha': 9.605102561377187e-06, 'reg_lambda': 0.20912152216971558}. Best is trial 8 with value: 0.7644367599604345.
# 2025-03-26 19:05:48 - Loading datasets...
# 2025-03-26 19:05:49 - Training data shape: (21508, 3)
# 2025-03-26 19:05:49 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:05:49 - Training XGBoost with hyperparameters: {'max_depth': 8, 'learning_rate': 0.001867828016134347, 'n_estimators': 611, 'min_child_weight': 5, 'gamma': 2.132802687540773e-07, 'subsample': 0.678485365839757, 'colsample_bytree': 0.6636351616171391, 'reg_alpha': 5.9295162064427164e-06, 'reg_lambda': 1.3729346149616295e-05, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [I 2025-03-26 19:06:02,721] Trial 1 finished with value: 0.607102296650199 and parameters: {'max_features': 10000, 'min_df': 1, 'ngram_range': (1, 1), 'max_depth': 4, 'learning_rate': 0.00011376986738937159, 'n_estimators': 714, 'min_child_weight': 2, 'gamma': 0.000904983303502658, 'subsample': 0.779524762824769, 'colsample_bytree': 0.6652001476102487, 'reg_alpha': 0.006474622747694848, 'reg_lambda': 2.0194515748007183e-08}. Best is trial 8 with value: 0.7644367599604345.
# 2025-03-26 19:06:02 - Loading datasets...
# [I 2025-03-26 19:06:04,759] Trial 0 finished with value: 0.7838379942458528 and parameters: {'max_features': 5000, 'min_df': 2, 'ngram_range': (1, 3), 'max_depth': 4, 'learning_rate': 0.158925074108929, 'n_estimators': 864, 'min_child_weight': 6, 'gamma': 0.013937552566816211, 'subsample': 0.9950336178324377, 'colsample_bytree': 0.5732174199977808, 'reg_alpha': 1.4795894642524775e-07, 'reg_lambda': 2.321952753677158e-07}. Best is trial 0 with value: 0.7838379942458528.
# 2025-03-26 19:06:04 - Loading datasets...
# 2025-03-26 19:06:04 - Training data shape: (21508, 3)
# 2025-03-26 19:06:04 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:06:05 - Training XGBoost with hyperparameters: {'max_depth': 10, 'learning_rate': 0.22850323971480613, 'n_estimators': 986, 'min_child_weight': 7, 'gamma': 0.7712238304308572, 'subsample': 0.6596723536344062, 'colsample_bytree': 0.7744833089503033, 'reg_alpha': 1.9837421481176234e-06, 'reg_lambda': 1.7537348659056792e-06, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# 2025-03-26 19:06:07 - Training data shape: (21508, 3)
# 2025-03-26 19:06:07 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:06:09 - Training XGBoost with hyperparameters: {'max_depth': 6, 'learning_rate': 0.24442314598161397, 'n_estimators': 988, 'min_child_weight': 7, 'gamma': 3.3857990283659666e-06, 'subsample': 0.6627814592155843, 'colsample_bytree': 0.7604447238210825, 'reg_alpha': 2.357823767149488e-06, 'reg_lambda': 2.7474207290503404e-08, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:06:21,816] Trial 6 finished with value: 0.662674762062103 and parameters: {'max_features': 20000, 'min_df': 1, 'ngram_range': (1, 1), 'max_depth': 5, 'learning_rate': 0.0034842774613547487, 'n_estimators': 515, 'min_child_weight': 1, 'gamma': 6.319905019320346e-07, 'subsample': 0.9361532363666731, 'colsample_bytree': 0.9102143521687318, 'reg_alpha': 1.010164612380545e-05, 'reg_lambda': 9.987364951376714e-06}. Best is trial 0 with value: 0.7838379942458528.
# 2025-03-26 19:06:21 - Loading datasets...
# ...
# [I 2025-03-26 19:39:11,765] Trial 80 finished with value: 0.7807310312684484 and parameters: {'max_features': 15000, 'min_df': 3, 'ngram_range': (1, 1), 'max_depth': 5, 'learning_rate': 0.0998233150195227, 'n_estimators': 956, 'min_child_weight': 3, 'gamma': 1.1916182093893565e-07, 'subsample': 0.5685291950923465, 'colsample_bytree': 0.9196973339439719, 'reg_alpha': 3.510516705698483e-08, 'reg_lambda': 0.00018736178744439431}. Best is trial 36 with value: 0.7848242833616839.
# 2025-03-26 19:39:11 - Loading datasets...
# 2025-03-26 19:39:12 - Training data shape: (21508, 3)
# 2025-03-26 19:39:12 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:39:12 - Training XGBoost with hyperparameters: {'max_depth': 6, 'learning_rate': 0.20236080114261462, 'n_estimators': 869, 'min_child_weight': 4, 'gamma': 4.770146166336706e-08, 'subsample': 0.5206583050408251, 'colsample_bytree': 0.9814701901316155, 'reg_alpha': 0.05491825585169764, 'reg_lambda': 0.19339606678371773, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:39:37,222] Trial 87 finished with value: 0.7800955224770424 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.10672944299967639, 'n_estimators': 946, 'min_child_weight': 7, 'gamma': 6.5778848551969e-08, 'subsample': 0.5860503870538322, 'colsample_bytree': 0.8002100893240868, 'reg_alpha': 0.0004744676260491874, 'reg_lambda': 5.436438485433296e-05}. Best is trial 36 with value: 0.7848242833616839.
# 2025-03-26 19:39:37 - Loading datasets...
# 2025-03-26 19:39:38 - Training data shape: (21508, 3)
# 2025-03-26 19:39:38 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:39:38 - Training XGBoost with hyperparameters: {'max_depth': 6, 'learning_rate': 0.2058462016868435, 'n_estimators': 873, 'min_child_weight': 4, 'gamma': 5.16694407392411e-07, 'subsample': 0.5241013310152313, 'colsample_bytree': 0.9839662605603635, 'reg_alpha': 0.18647786552598417, 'reg_lambda': 0.5612606964245678, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:39:42,682] Trial 82 finished with value: 0.7793870953674317 and parameters: {'max_features': 15000, 'min_df': 3, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.10354795424675241, 'n_estimators': 941, 'min_child_weight': 4, 'gamma': 1.0815176967137945e-07, 'subsample': 0.8119707094918996, 'colsample_bytree': 0.5252780157068594, 'reg_alpha': 0.032231736666618514, 'reg_lambda': 6.797492109230871e-07}. Best is trial 36 with value: 0.7848242833616839.
# 2025-03-26 19:39:42 - Loading datasets...
# 2025-03-26 19:39:46 - Training data shape: (21508, 3)
# 2025-03-26 19:39:46 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:39:49 - Training XGBoost with hyperparameters: {'max_depth': 6, 'learning_rate': 0.19335449418874492, 'n_estimators': 877, 'min_child_weight': 4, 'gamma': 3.97283535825967e-07, 'subsample': 0.5210879113008956, 'colsample_bytree': 0.9783112182290183, 'reg_alpha': 0.17072380987111557, 'reg_lambda': 0.5172658731060149, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:40:03,509] Trial 92 finished with value: 0.7805748060728179 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.20545870075051648, 'n_estimators': 969, 'min_child_weight': 4, 'gamma': 5.5712747012538165e-08, 'subsample': 0.5855681666333667, 'colsample_bytree': 0.8893791167361488, 'reg_alpha': 0.0008097729711593454, 'reg_lambda': 4.014850106116084e-05}. Best is trial 36 with value: 0.7848242833616839.
# 2025-03-26 19:40:03 - Loading datasets...
# 2025-03-26 19:40:03 - Training data shape: (21508, 3)
# 2025-03-26 19:40:04 - Development data shape: (5926, 3)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\optuna\distributions.py:515: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# 2025-03-26 19:40:04 - Training XGBoost with hyperparameters: {'max_depth': 6, 'learning_rate': 0.18909771472216935, 'n_estimators': 869, 'min_child_weight': 3, 'gamma': 5.691985758089821e-07, 'subsample': 0.5233620138846841, 'colsample_bytree': 0.9751490476581894, 'reg_alpha': 0.11832806076287412, 'reg_lambda': 0.264096210290397, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'use_label_encoder': False, 'tree_method': 'hist', 'random_state': 42}
# [I 2025-03-26 19:40:10,388] Trial 85 finished with value: 0.7828454314329889 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.10660199121129182, 'n_estimators': 948, 'min_child_weight': 3, 'gamma': 2.0463765540972763e-07, 'subsample': 0.5283559509542636, 'colsample_bytree': 0.921711181358312, 'reg_alpha': 0.00157955213178049, 'reg_lambda': 0.0017902894986164119}. Best is trial 36 with value: 0.7848242833616839.
# [I 2025-03-26 19:40:28,405] Trial 88 finished with value: 0.7842027529473817 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.10923903338731283, 'n_estimators': 950, 'min_child_weight': 7, 'gamma': 8.838741485628252e-08, 'subsample': 0.5920122797255509, 'colsample_bytree': 0.7982424570944051, 'reg_alpha': 0.0006905305105596958, 'reg_lambda': 5.072465257057586e-05}. Best is trial 36 with value: 0.7848242833616839.
# [I 2025-03-26 19:40:31,802] Trial 81 finished with value: 0.7803287394131726 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.10599644026074719, 'n_estimators': 934, 'min_child_weight': 4, 'gamma': 1.5661507375809311e-07, 'subsample': 0.8638045746006063, 'colsample_bytree': 0.5243398783371231, 'reg_alpha': 3.717464071620764e-08, 'reg_lambda': 0.00019666680878070554}. Best is trial 36 with value: 0.7848242833616839.
# [I 2025-03-26 19:40:35,616] Trial 84 finished with value: 0.7833374638148747 and parameters: {'max_features': 15000, 'min_df': 2, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.09998238591495665, 'n_estimators': 950, 'min_child_weight': 3, 'gamma': 7.768623703190637e-08, 'subsample': 0.5223415098296333, 'colsample_bytree': 0.5246177781979577, 'reg_alpha': 3.3340088816276236e-08, 'reg_lambda': 5.0690733960706425e-05}. Best is trial 36 with value: 0.7848242833616839.
# [I 2025-03-26 19:40:52,367] Trial 95 finished with value: 0.7814334753105723 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.19575078815709704, 'n_estimators': 941, 'min_child_weight': 4, 'gamma': 0.276638221113363, 'subsample': 0.5921216625683198, 'colsample_bytree': 0.8964314134681522, 'reg_alpha': 0.0003284120955157442, 'reg_lambda': 4.488185365783823e-05}. Best is trial 36 with value: 0.7848242833616839.
# [I 2025-03-26 19:41:00,908] Trial 94 pruned.
# [I 2025-03-26 19:41:02,091] Trial 93 finished with value: 0.7781849580283465 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.20837465638352143, 'n_estimators': 870, 'min_child_weight': 4, 'gamma': 0.2978808958724126, 'subsample': 0.5214635978758608, 'colsample_bytree': 0.9115092525267241, 'reg_alpha': 0.0005170515200960883, 'reg_lambda': 4.873562200369242e-05}. Best is trial 36 with value: 0.7848242833616839.
# [I 2025-03-26 19:41:07,250] Trial 96 finished with value: 0.7757574721690277 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.20236080114261462, 'n_estimators': 869, 'min_child_weight': 4, 'gamma': 4.770146166336706e-08, 'subsample': 0.5206583050408251, 'colsample_bytree': 0.9814701901316155, 'reg_alpha': 0.05491825585169764, 'reg_lambda': 0.19339606678371773}. Best is trial 36 with value: 0.7848242833616839.
# [I 2025-03-26 19:41:07,414] Trial 83 finished with value: 0.7831247071940787 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.09767204953021084, 'n_estimators': 950, 'min_child_weight': 3, 'gamma': 1.740617943550419e-07, 'subsample': 0.8126008885920711, 'colsample_bytree': 0.524910307426663, 'reg_alpha': 0.0129698690186181, 'reg_lambda': 0.00019687880376812903}. Best is trial 36 with value: 0.7848242833616839.
# [I 2025-03-26 19:41:24,574] Trial 86 finished with value: 0.7862936515178504 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.10437109564495202, 'n_estimators': 949, 'min_child_weight': 7, 'gamma': 9.957755835836044e-08, 'subsample': 0.8633107968594791, 'colsample_bytree': 0.9196679493967628, 'reg_alpha': 0.0007388500492709971, 'reg_lambda': 4.991341546894774e-05}. Best is trial 86 with value: 0.7862936515178504.
# [I 2025-03-26 19:41:30,073] Trial 97 finished with value: 0.7803292705066693 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.2058462016868435, 'n_estimators': 873, 'min_child_weight': 4, 'gamma': 5.16694407392411e-07, 'subsample': 0.5241013310152313, 'colsample_bytree': 0.9839662605603635, 'reg_alpha': 0.18647786552598417, 'reg_lambda': 0.5612606964245678}. Best is trial 86 with value: 0.7862936515178504.
# [I 2025-03-26 19:41:36,878] Trial 89 finished with value: 0.7820719794036053 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.09795724231794749, 'n_estimators': 942, 'min_child_weight': 4, 'gamma': 9.287907958737172e-08, 'subsample': 0.8612301038974696, 'colsample_bytree': 0.5222350337494689, 'reg_alpha': 6.844053720281491e-05, 'reg_lambda': 0.29723528616488815}. Best is trial 86 with value: 0.7862936515178504.
# [I 2025-03-26 19:41:38,951] Trial 90 finished with value: 0.7813380083677097 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.09900275485142389, 'n_estimators': 963, 'min_child_weight': 4, 'gamma': 1.0810724998446863e-07, 'subsample': 0.8035519636949839, 'colsample_bytree': 0.9780357346230488, 'reg_alpha': 0.0006131335797523607, 'reg_lambda': 0.3425034103787266}. Best is trial 86 with value: 0.7862936515178504.
# [I 2025-03-26 19:41:39,194] Trial 98 finished with value: 0.7779124259262685 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.19335449418874492, 'n_estimators': 877, 'min_child_weight': 4, 'gamma': 3.97283535825967e-07, 'subsample': 0.5210879113008956, 'colsample_bytree': 0.9783112182290183, 'reg_alpha': 0.17072380987111557, 'reg_lambda': 0.5172658731060149}. Best is trial 86 with value: 0.7862936515178504.
# [I 2025-03-26 19:41:44,110] Trial 99 finished with value: 0.7772637858863967 and parameters: {'max_features': 20000, 'min_df': 2, 'ngram_range': (1, 2), 'max_depth': 6, 'learning_rate': 0.18909771472216935, 'n_estimators': 869, 'min_child_weight': 3, 'gamma': 5.691985758089821e-07, 'subsample': 0.5233620138846841, 'colsample_bytree': 0.9751490476581894, 'reg_alpha': 0.11832806076287412, 'reg_lambda': 0.264096210290397}. Best is trial 86 with value: 0.7862936515178504.
# [I 2025-03-26 19:41:56,543] Trial 91 finished with value: 0.7744946678816454 and parameters: {'max_features': 15000, 'min_df': 1, 'ngram_range': (1, 3), 'max_depth': 6, 'learning_rate': 0.04865844669631596, 'n_estimators': 960, 'min_child_weight': 4, 'gamma': 8.946751249981945e-08, 'subsample': 0.9585791904272729, 'colsample_bytree': 0.97725901760007, 'reg_alpha': 0.000480951848240467, 'reg_lambda': 0.34529631106133046}. Best is trial 86 with value: 0.7862936515178504.
# Best trial:
#   Value (Accuracy): 0.7862936515178504
#   Params:
#     max_features: 15000
#     min_df: 1
#     ngram_range: (1, 2)
#     max_depth: 6
#     learning_rate: 0.10437109564495202
#     n_estimators: 949
#     min_child_weight: 7
#     gamma: 9.957755835836044e-08
#     subsample: 0.8633107968594791
#     colsample_bytree: 0.9196679493967628
#     reg_alpha: 0.0007388500492709971
#     reg_lambda: 4.991341546894774e-05
