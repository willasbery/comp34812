# %%
import logging
import pandas as pd
from pathlib import Path
from googletrans import Translator
from typing import AsyncGenerator


# Set up logging
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO)

# %%
# Path configuration
DATA_DIR = Path('./data')
TRAIN_PATH = DATA_DIR / 'train.csv'
DEV_PATH = DATA_DIR / 'dev.csv'
AUGMENTED_DATA_PATH = DATA_DIR / 'train_augmented.csv'

# %%
def format_text(text: str) -> str:
    # Replace all double quotes with single quotes
    text = text.replace('\"', "\'")
    
    # If the text starts with a double quote, remove it
    text = text[1:] if text.startswith('"') else text

    # If the text ends with a double quote, remove it
    text = text[:-1] if text.endswith('"') else text
    
    # If the text contains a commma, or a single quote, wrap it in double quotes
    text = f'"{text}"' if ',' in text or "'" in text else text
        
    # If the text contains unrepresentable characters, replace them with a space
    text = text.encode('ascii', 'ignore').decode('ascii')
    
    return text


async def back_translate(text: str, src='en', intermediate='fr') -> str:
    async with Translator() as translator:
        to_french = await translator.translate(text, src=src, dest=intermediate, )
        back_to_english = await translator.translate(
            to_french.text, 
            src=intermediate, 
            dest=src
        )
        return back_to_english.text


async def process_data_stream(train_path: Path, dev_path: Path, augmented_data: pd.DataFrame) -> AsyncGenerator[dict, None]:
    train_df = pd.read_csv(train_path)
    positive_examples = train_df[train_df['label'] == 1]
    
    for idx, row in positive_examples.iterrows():
        if row['Evidence'] in augmented_data['Original Evidence'].values:
            # Skip this example as it's already been processed
            logging.info(f"Skipping example {idx} as it's already been processed")
            continue
        
        original_evidence = row['Evidence']
        translated_evidence = await back_translate(original_evidence)
        
        yield {
            'claim': row['Claim'],
            'original_evidence': original_evidence,
            'translated_evidence': translated_evidence,
            'index': idx
        }

# %%
augmented_data = pd.read_csv(AUGMENTED_DATA_PATH)

async for item in process_data_stream(TRAIN_PATH, DEV_PATH, augmented_data):
    translated_evidence = format_text(item['translated_evidence'])
    original_evidence = format_text(item['original_evidence'])
    claim = format_text(item['claim'])
    
    with open(AUGMENTED_DATA_PATH, 'a') as f:
        f.write(f'{claim},{translated_evidence},{original_evidence},1\n')
        
    # Log the augmented data
    logging.info(f"Added augmented data for claim: {claim[:30]}...")
    
    # Save to the augmented dataframe as well
    new_row = pd.DataFrame({
        'Claim': [claim], 
        'Evidence': [translated_evidence], 
        'Original Evidence': [original_evidence],
        'label': [1]
    })
    augmented_data = pd.concat([augmented_data, new_row], ignore_index=True)
# Out:
# 2025-03-27 16:28:29 - HTTP Request: GET https://translate.googleapis.com/translate_a/single?client=gtx&sl=en&tl=fr&hl=fr&dt=at&dt=bd&dt=ex&dt=ld&dt=md&dt=qca&dt=rw&dt=rm&dt=ss&dt=t&ie=UTF-8&oe=UTF-8&otf=1&ssel=0&tsel=0&tk=xxxx&q=a+2001+survey+by+the+European+Commission+found+that+%22only+10.1+percent+of+Europeans+trusted+the+nuclear+industry "HTTP/2 200 OK"
# 2025-03-27 16:28:29 - HTTP Request: GET https://translate.googleapis.com/translate_a/single?client=gtx&sl=fr&tl=en&hl=en&dt=at&dt=bd&dt=ex&dt=ld&dt=md&dt=qca&dt=rw&dt=rm&dt=ss&dt=t&ie=UTF-8&oe=UTF-8&otf=1&ssel=0&tsel=0&tk=xxxx&q
dt=at&dt=bd&dt=ex&dt=ld&dt=md&dt=qca&dt=rw&dt=rm&dt=ss&dt=t&ie=UTF-8&oe=UTF-8&otf=1&ssel=0&tsel=0&tk=xxxx&q=Amory+Lovins%2C+du+Rocky+Mountain+Institute%2C+a+soutenu+que+les+syst%C3%A8mes+d%27%C3%A9lectricit%C3%A9+centralis%C3%A9s+avec+des+centrales+%C3%A9lectriques+g%C3%A9antes+deviennent+obsol%C3%A8tes.+%C3%80+leur+place+se+trouvent+des+sources+d%27approvisionnement+en+%C3%A9lectricit%C3%A9+d%C3%A9centralis%C3%A9es+%28les+ressources+distribu%C3%A9es+%22et+plus+malliennes+%28y+compris+l%27efficacit%C3%A9%29+qui+sont+moins+ch%C3%A8res%2C+plus+propres%2C+moins+risqu%C3%A9es%2C+plus+flexibles+et+plus+rapides.+De+telles+technologies+sont+souvent+appel%C3%A9es+%C2%ABtechnologies+d%27%C3%A9nergie+douce%C2%BB+et+les+amour+consid%C3%A9raient+leurs+impacts+comme+des+technologies+plus+douces%2C+agr%C3%A9ables+et+g%C3%A9rables+que+l%27%C3%A9nergie+dure+telles+que+l%27%C3%A9nergie+nucl%C3%A9aire+%5Bref "HTTP/2 200 OK"
# 2025-03-27 16:28:35 - Added augmented data for claim: We should further exploit nucl...
# 2025-03-27 16:28:35 - Skipping example 470 as it's already been processed
# 2025-03-27 16:28:35 - Skipping example 473 as it's already been processed
# 2025-03-27 16:28:35 - Skipping example 480 as it's already been processed
# 2025-03-27 16:28:35 - Skipping example 481 as it's already been processed
# 2025-03-27 16:28:35 - Skipping example 488 as it's already been processed
# 2025-03-27 16:28:35 - Skipping example 491 as it's already been processed
# 2025-03-27 16:28:35 - Skipping example 505 as it's already been processed
# 2025-03-27 16:28:35 - HTTP Request: GET https://translate.googleapis.com/translate_a/single?client=gtx&sl=en&tl=fr&hl=fr&dt=at&dt=bd&dt=ex&dt=ld&dt=md&dt=qca&dt=rw&dt=rm&dt=ss&dt=t&ie=UTF-8&oe=UTF-8&otf=1&ssel=0&tsel=0&tk=xxxx&q=In+the+developing+world%2C+companies+like+eHi%2C%5BREF%5D+Carrot%2C%5BREF%5D%5BREF%5D+Zazcar%5BREF%5D+and+Zoom+have+replicated+or+modified+Zipcar%27s+business+model+to+improve+urban+transportation+to+provide+a+broader+audience+with+greater+access+to+the+benefits+of+a+car+and+provide%22last-mile%22+connectivity+between+public+transportation+and+an+individual%27s+destination. "HTTP/2 200 OK"
# 2025-03-27 16:28:35 - HTTP Request: GET https://translate.googleapis.com/translate_a/single?client=gtx&sl=fr&tl=en&hl=en&dt=at&dt=bd&dt=ex&dt=ld&dt=md&dt=qca&dt=rw&dt=rm&dt=ss&dt=t&ie=UTF-8&oe=UTF-8&otf=1&ssel=0&tsel=0&tk=xxxx&q=Dans+le+monde+en+d%C3%A9veloppement%2C+des+entreprises+comme+EHI%2C+%5BRef%5D+Carrot%2C+%5BRef%5D+%5BRef%5D+Zazcar+%5BRef%5D+et+Zoom+ont+reproduit+ou+modifi%C3%A9+le+mod%C3%A8le+commercial+de+Zipcar+pour+am%C3%A9liorer+le+transport+urbain+pour+fournir+%C3%A0+un+public+plus+large+un+meilleur+acc%C3%A8s+aux+avantages+d%27une+voiture+et+fournir+une+connectivit%C3%A9+%22dernier+mille%22+entre+les+transports+publics+et+la+destination+d%27une+personne. "HTTP/2 200 OK"
# 2025-03-27 16:28:35 - Added augmented data for claim: We should subsidize public tra...
# 2025-03-27 16:28:35 - Skipping example 513 as it's already been processed
# 2025-03-27 16:28:35 - Skipping example 515 as it's already been processed
# 2025-03-27 16:28:35 - HTTP Request: GET https://translate.googleapis.com/translate_a/single?client=gtx&sl=en&tl=fr&hl=fr&dt=at&dt=bd&dt=ex&dt=ld&dt=md&dt=qca&dt=rw&dt=rm&dt=ss&dt=t&ie=UTF-8&oe=UTF-8&otf=1&ssel=0&tsel=0&tk=xxxx&q=A+2006+survey+concluded+that+a+majority+%2863%25%29+of+EU+citizens+%22show+some+willingness+to+change+their+usual+place+of+shopping+in+order+to+be+able+to+purchase+more+animal+welfare-friendly+products.%22%5BREF "HTTP/2 200 OK"
# 2025-03-27 16:28:35 - HTTP Request: GET https://translate.googleapis.com/translate_a/single?client=gtx&sl
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 augmented_data = pd.read_csv(AUGMENTED_DATA_PATH)
# ----> 3 async for item in process_data_stream(TRAIN_PATH, DEV_PATH, augmented_data):
#       4     translated_evidence = format_text(item['translated_evidence'])
#       5     original_evidence = format_text(item['original_evidence'])
#
# Cell In[3], line 42, in process_data_stream(train_path, dev_path, augmented_data)
#      39     continue
#      41 original_evidence = row['Evidence']
# ---> 42 translated_evidence = await back_translate(original_evidence)
#      44 yield {
#      45     'claim': row['Claim'],
#      46     'original_evidence': original_evidence,
#      47     'translated_evidence': translated_evidence,
#      48     'index': idx
#      49 }
#
# Cell In[3], line 23, in back_translate(text, src, intermediate)
#      21 async with Translator() as translator:
#      22     to_french = await translator.translate(text, src=src, dest=intermediate, )
# ---> 23     back_to_english = await translator.translate(
#      24         to_french.text,
#      25         src=intermediate,
#      26         dest=src
#      27     )
#      28     return back_to_english.text
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\googletrans\client.py:286, in Translator.translate(self, text, dest, src, **kwargs)
#     283     return result
#     285 origin = text
# --> 286 data, response = await self._translate(text, dest, src, kwargs)
#     288 # this code will be updated when the format is changed.
#     289 translated = "".join([d[0] if d[0] else "" for d in data[0]])
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\googletrans\client.py:128, in Translator._translate(self, text, dest, src, override)
#     118 params = utils.build_params(
#     119     client=self.client_type,
#     120     query=text,
#    (...)    124     override=override,
#     125 )
#     127 url = urls.TRANSLATE.format(host=self._pick_service_url())
# --> 128 r = await self.client.get(url, params=params)
#     130 if r.status_code == 200:
#     131     data = utils.format_json(r.text)
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpx\_client.py:1768, in AsyncClient.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1751 async def get(
#    1752     self,
#    1753     url: URL | str,
#    (...)   1761     extensions: RequestExtensions | None = None,
#    1762 ) -> Response:
#    1763     """
#    1764     Send a `GET` request.
#    1765
#    1766     **Parameters**: See `httpx.request`.
#    1767     """
# -> 1768     return await self.request(
#    1769         "GET",
#    1770         url,
#    1771         params=params,
#    1772         headers=headers,
#    1773         cookies=cookies,
#    1774         auth=auth,
#    1775         follow_redirects=follow_redirects,
#    1776         timeout=timeout,
#    1777         extensions=extensions,
#    1778     )
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpx\_client.py:1540, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1525     warnings.warn(message, DeprecationWarning, stacklevel=2)
#    1527 request = self.build_request(
#    1528     method=method,
#    1529     url=url,
#    (...)   1538     extensions=extensions,
#    1539 )
# -> 1540 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpx\_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1625 self._set_timeout(request)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#    1636     if not stream:
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpx\_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1654 request = await auth_flow.__anext__()
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#    1663         try:
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpx\_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1691 for hook in self._event_hooks["request"]:
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#    1696     for hook in self._event_hooks["response"]:
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpx\_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1725     raise RuntimeError(
#    1726         "Attempted to send an sync request with an AsyncClient instance."
#    1727     )
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#    1733 response.request = request
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpx\_transports\default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#     398 return Response(
#     399     status_code=resp.status,
#     400     headers=resp.headers,
#     401     stream=AsyncResponseStream(resp.stream),
#     402     extensions=resp.extensions,
#     403 )
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.AsyncIterable)
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     232 connection = await pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return await self._connection.handle_async_request(request)
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\http2.py:183, in AsyncHTTP2Connection.handle_async_request(self, request)
#     179     # If h2 raises a protocol error in some other state then we
#     180     # must somehow have made a protocol violation.
#     181     raise LocalProtocolError(exc)  # pragma: nocover
# --> 183 raise exc
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\http2.py:146, in AsyncHTTP2Connection.handle_async_request(self, request)
#     142     await self._send_request_body(request=request, stream_id=stream_id)
#     143 async with Trace(
#     144     "receive_response_headers", logger, request, kwargs
#     145 ) as trace:
# --> 146     status, headers = await self._receive_response(
#     147         request=request, stream_id=stream_id
#     148     )
#     149     trace.return_value = (status, headers)
#     151 return Response(
#     152     status=status,
#     153     headers=headers,
#    (...)    159     },
#     160 )
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\http2.py:290, in AsyncHTTP2Connection._receive_response(self, request, stream_id)
#     286 """
#     287 Return the response status code and headers for a given stream ID.
#     288 """
#     289 while True:
# --> 290     event = await self._receive_stream_event(request, stream_id)
#     291     if isinstance(event, h2.events.ResponseReceived):
#     292         break
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\http2.py:329, in AsyncHTTP2Connection._receive_stream_event(self, request, stream_id)
#     323 """
#     324 Return the next available event for a given stream ID.
#     325
#     326 Will read more data from the network if required.
#     327 """
#     328 while not self._events.get(stream_id):
# --> 329     await self._receive_events(request, stream_id)
#     330 event = self._events[stream_id].pop(0)
#     331 if isinstance(event, h2.events.StreamReset):
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\http2.py:357, in AsyncHTTP2Connection._receive_events(self, request, stream_id)
#     350 # This conditional is a bit icky. We don't want to block reading if we've
#     351 # actually got an event to return for a given stream. We need to do that
#     352 # check *within* the atomic read lock. Though it also need to be optional,
#     353 # because when we call it from `_wait_for_outgoing_flow` we *do* want to
#     354 # block until we've available flow control, event when we have events
#     355 # pending for the stream ID we're attempting to send on.
#     356 if stream_id is None or not self._events.get(stream_id):
# --> 357     events = await self._read_incoming_data(request)
#     358     for event in events:
#     359         if isinstance(event, h2.events.RemoteSettingsChanged):
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_async\http2.py:432, in AsyncHTTP2Connection._read_incoming_data(self, request)
#     429     raise self._read_exception  # pragma: nocover
#     431 try:
# --> 432     data = await self._network_stream.read(self.READ_NUM_BYTES, timeout)
#     433     if data == b"":
#     434         raise RemoteProtocolError("Server disconnected")
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\httpcore\_backends\anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      33 with anyio.fail_after(timeout):
#      34     try:
# ---> 35         return await self._stream.receive(max_bytes=max_bytes)
#      36     except anyio.EndOfStream:  # pragma: nocover
#      37         return b""
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\anyio\streams\tls.py:219, in TLSStream.receive(self, max_bytes)
#     218 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 219     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     220     if not data:
#     221         raise EndOfStream
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\anyio\streams\tls.py:162, in TLSStream._call_sslobject_method(self, func, *args)
#     159     if self._write_bio.pending:
#     160         await self.transport_stream.send(self._write_bio.read())
# --> 162     data = await self.transport_stream.receive()
#     163 except EndOfStream:
#     164     self._read_bio.write_eof()
#
# File c:\Users\willi\Desktop\Uni\3rd_year\NLU\comp38412-not-broken\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:1254, in SocketStream.receive(self, max_bytes)
#    1248 if (
#    1249     not self._protocol.read_event.is_set()
#    1250     and not self._transport.is_closing()
#    1251     and not self._protocol.is_at_eof
#    1252 ):
#    1253     self._transport.resume_reading()
# -> 1254     await self._protocol.read_event.wait()
#    1255     self._transport.pause_reading()
#    1256 else:
#
# File C:\Python311\Lib\asyncio\locks.py:213, in Event.wait(self)
#     211 self._waiters.append(fut)
#     212 try:
# --> 213     await fut
#     214     return True
#     215 finally:
#
# CancelledError:
